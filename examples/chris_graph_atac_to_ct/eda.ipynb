# %%
import logging

import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc

# %%
# Init file paths
file_path_training = '/Users/cheshic/dev/test_data/neurips-2021/multiome/multiome_atac_processed_training.h5ad'

# Load data
sc_raw_training = sc.read(file_path_training)

# %%
sc_raw_training.obs
# Out:
#                          nCount_peaks  atac_fragments  reads_in_peaks_frac  \
# TAGTTGTCACCCTCAC-1-s1d1        4031.0            5400             0.746481
# CTATGGCCATAACGGG-1-s1d1        8636.0           19266             0.448251
# CCGCACACAGGTTAAA-1-s1d1        4674.0            6177             0.756678
# TCATTTGGTAATGGAA-1-s1d1        2803.0            4019             0.697437
# ACCACATAGGTGTCCA-1-s1d1        1790.0            2568             0.697040
# ...                               ...             ...                  ...
# TAGTAAGCAACTAGGG-8-s3d6        7239.0           10580             0.684216
# TGGTCCTTCGGCTAGC-8-s3d6       16056.0           22771             0.705107
# CGCTTGCGTTGTTGGA-8-s3d6        8388.0           14137             0.593337
# ACCCTCCCAGCCAGTT-8-s3d6        1001.0            1381             0.724837
# AGTGAACCATCCCGCT-8-s3d6        3183.0            4684             0.679547
#
#                          blacklist_fraction  nucleosome_signal  \
# TAGTTGTCACCCTCAC-1-s1d1            0.003473           0.642468
# CTATGGCCATAACGGG-1-s1d1            0.003126           1.220679
# CCGCACACAGGTTAAA-1-s1d1            0.001284           0.692573
# TCATTTGGTAATGGAA-1-s1d1            0.000714           0.633838
# ACCACATAGGTGTCCA-1-s1d1            0.003352           0.727660
# ...                                     ...                ...
# TAGTAAGCAACTAGGG-8-s3d6            0.000553           0.866142
# TGGTCCTTCGGCTAGC-8-s3d6            0.000810           0.964006
# CGCTTGCGTTGTTGGA-8-s3d6            0.000358           1.215227
# ACCCTCCCAGCCAGTT-8-s3d6            0.000000           0.714286
# AGTGAACCATCCCGCT-8-s3d6            0.001257           0.946565
#
#                                 cell_type  pseudotime_order_ATAC batch
# TAGTTGTCACCCTCAC-1-s1d1     Naive CD20+ B                    NaN  s1d1
# CTATGGCCATAACGGG-1-s1d1        CD14+ Mono                    NaN  s1d1
# CCGCACACAGGTTAAA-1-s1d1            CD8+ T                    NaN  s1d1
# TCATTTGGTAATGGAA-1-s1d1            CD8+ T                    NaN  s1d1
# ACCACATAGGTGTCCA-1-s1d1        CD16+ Mono                    NaN  s1d1
# ...                                   ...                    ...   ...
# TAGTAAGCAACTAGGG-8-s3d6               HSC                0.23367  s3d6
# TGGTCCTTCGGCTAGC-8-s3d6  CD4+ T activated                    NaN  s3d6
# CGCTTGCGTTGTTGGA-8-s3d6               pDC                    NaN  s3d6
# ACCCTCCCAGCCAGTT-8-s3d6            CD8+ T                    NaN  s3d6
# AGTGAACCATCCCGCT-8-s3d6  CD4+ T activated                    NaN  s3d6
#
# [22463 rows x 8 columns]

# %%
sc_raw_training.var
# Out:
#                         feature_types
# chr1-9776-10668                  ATAC
# chr1-180726-181005               ATAC
# chr1-181117-181803               ATAC
# chr1-191133-192055               ATAC
# chr1-267562-268456               ATAC
# ...                               ...
# GL000219.1-90062-90937           ATAC
# GL000219.1-99257-100160          ATAC
# KI270726.1-27152-28034           ATAC
# KI270713.1-21434-22336           ATAC
# KI270713.1-29629-30491           ATAC
#
# [116490 rows x 1 columns]

# %%
# convert to list of lists format
matrix = sc_raw_training.X.tocoo()
matrix.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/m4wl6mfj0pq4445vvxg8c458fthlkc/T/ipykernel_16467/4096823006.py in <module>
#       1 # convert to list of lists format
# ----> 2 matrix = sc_raw_training.X.tocoo()
#       3 matrix.shape
#
# NameError: name 'sc_raw_training' is not defined

# %%
# Print different formats
for i,j,v in zip(matrix.row, matrix.col, matrix.data):
    #print((i,j,v))
    #print((sc_raw_training.obs.index[i], sc_raw_training.var.index[j], v))
    
    line = sc_raw_training.obs.index[i] + "\t" + sc_raw_training.var.index[j] + "\t" + str(v)
    #print(line)
    
    line = sc_raw_training.obs.index[i] + "\tatac_peak\t" + sc_raw_training.var.index[j]
    #print(line)
    
    line1 = str(i) + "\tcell_peak\t" + str(j)
    print(line1)
    break

# %%
df_embed = pd.read_csv('data/embeddings.tsv', header=None, sep='\t', index_col=0)
df_embed
# Out:
#                   1         2         3         4         5         6    \
# 0
# peak-59662  -0.046500 -0.109772  0.204643  0.081796  0.091679 -0.035572
# peak-90595   0.123306  0.073625  0.053199 -0.124275 -0.010957  0.025096
# peak-101006 -0.080310  0.076826 -0.125076  0.082620  0.002942 -0.071995
# peak-18639  -0.507438  0.048056 -0.017927 -0.201939  0.072424 -0.039708
# peak-38506   0.184786 -0.140684  0.027488  0.188033 -0.145896 -0.031585
# ...               ...       ...       ...       ...       ...       ...
# peak-61770  -0.082917 -0.019807  0.077282  0.182612  0.070893  0.006134
# cell-6829    0.030721 -0.191248  0.200946  0.076422  0.018137 -0.146683
# peak-79286   0.105057 -0.096547  0.040671  0.004324  0.151388 -0.109715
# peak-32955  -0.324569  0.137592  0.115677  0.097803  0.034763 -0.000371
# cell-10096  -0.150672 -0.018539 -0.091037 -0.119200  0.582847  0.161363
#
#                   7         8         9         10   ...       91        92   \
# 0                                                    ...
# peak-59662   0.041827  0.347262 -0.301920  0.268307  ... -0.181200  0.554349
# peak-90595   0.238045  0.327368 -0.102742  0.017951  ... -0.088350 -0.246188
# peak-101006 -0.150579  0.060043 -0.012554 -0.185023  ... -0.030086  0.332205
# peak-18639   0.041313  0.387210  0.073132 -0.058328  ...  0.163103  0.094812
# peak-38506   0.188290 -0.025428  0.173939 -0.057313  ...  0.280625 -0.248775
# ...               ...       ...       ...       ...  ...       ...       ...
# peak-61770   0.039605  0.185643 -0.077255 -0.055462  ... -0.045353 -0.135885
# cell-6829   -0.016632  0.248538  0.056343 -0.041786  ... -0.139150  0.107325
# peak-79286   0.078845  0.138902 -0.195856  0.137060  ... -0.250450 -0.378747
# peak-32955   0.168968  0.010623 -0.022125 -0.072607  ...  0.054632  0.041510
# cell-10096   0.178934 -0.038285  0.079848  0.115452  ... -0.277953 -0.216067
#
#                   93        94        95        96        97        98   \
# 0
# peak-59662   0.119330  0.218760  0.068921 -0.000014 -0.023290 -0.077101
# peak-90595  -0.023943  0.003305 -0.004752  0.056211  0.370873 -0.064962
# peak-101006  0.463441  0.142047 -0.301210  0.274227 -0.297529 -0.146073
# peak-18639  -0.204112  0.046364  0.141185 -0.226659  0.013859  0.098596
# peak-38506  -0.162693 -0.064450  0.064413  0.065176 -0.155508  0.056454
# ...               ...       ...       ...       ...       ...       ...
# peak-61770   0.056541  0.006131  0.105498 -0.046938  0.093870 -0.241207
# cell-6829    0.140100  0.002589 -0.459339 -0.328521 -0.008047 -0.003708
# peak-79286   0.089743  0.106809 -0.049472 -0.010511  0.026757 -0.125062
# peak-32955   0.056170  0.167516  0.135895 -0.111643  0.042460  0.000190
# cell-10096  -0.025832 -0.077225 -0.060897 -0.197393 -0.224690  0.041705
#
#                   99        100
# 0
# peak-59662  -0.091003 -0.313361
# peak-90595   0.095323 -0.154578
# peak-101006 -0.017667  0.096639
# peak-18639  -0.005096 -0.318385
# peak-38506  -0.058894 -0.114488
# ...               ...       ...
# peak-61770   0.053700 -0.052384
# cell-6829    0.108144  0.218628
# peak-79286   0.065996 -0.025884
# peak-32955  -0.110130  0.589739
# cell-10096  -0.290165 -0.330685
#
# [138953 rows x 100 columns]

# %%
df_embed_1 = df_embed[df_embed.index.str.contains("cell")]
df_embed_1['name'] = df_embed_1.index
df_embed_1[['type', 'id']] = df_embed_1['name'].str.split('-', expand=True)
# df_embed_1 = df_embed_1.sort_values('group')
df_embed_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22463 entries, cell-9446 to cell-10096
# Columns: 103 entries, 1 to id
# dtypes: float64(100), object(3)
# memory usage: 17.8+ MB
# /var/folders/3p/m4wl6mfj0pq4445vvxg8c458fthlkc/T/ipykernel_16467/3320928990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_embed_1['name'] = df_embed_1.index
# /usr/local/Caskroom/miniconda/base/envs/neurips-2021/lib/python3.9/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# Out:
# 34	cell_peak	0
